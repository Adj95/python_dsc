# %% [markdown]
# <a href="https://colab.research.google.com/github/Adj95/python_dsc/blob/main/Feature_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Feature Construction **

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/content/train (1).csv')[['Age','Pclass','SibSp','Parch','Survived']]
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
df.dropna(inplace = True)

# %%
x= df.iloc[: , 0:4]
y = df.iloc[: , -1]

# %%
x['family_size'] = x['SibSp'] + x['Parch'] + 1
x.head()
# Out:
#     Age  Pclass  SibSp  Parch  family_size
# 0  22.0       3      1      0            2
# 1  38.0       1      1      0            2
# 2  26.0       3      0      0            1
# 3  35.0       1      1      0            2
# 4  35.0       3      0      0            1

# %%
def myfunc(num):
  if num == 1:
    return 0
  elif num >1 and num<= 4:
    return 1
  else:
    return 2

# %%
x['family_type'] = x['family_size'].apply(myfunc)
x.head()
# Out:
#     Age  Pclass  SibSp  Parch  family_size  family_type
# 0  22.0       3      1      0            2            1
# 1  38.0       1      1      0            2            1
# 2  26.0       3      0      0            1            0
# 3  35.0       1      1      0            2            1
# 4  35.0       3      0      0            1            0

# %%
x.drop(columns = ['SibSp','Parch','family_size'],inplace = True)
x.head()
# Out:
#     Age  Pclass  family_type
# 0  22.0       3            1
# 1  38.0       1            1
# 2  26.0       3            0
# 3  35.0       1            1
# 4  35.0       3            0

# %%
np.mean(cross_val_score(LogisticRegression() ,x,y,scoring ='accuracy' , cv =20 ))
# Out:
# np.float64(0.7003174603174602)
