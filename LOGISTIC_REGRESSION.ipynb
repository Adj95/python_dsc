# %% [markdown]
# <a href="https://colab.research.google.com/github/Adj95/python_dsc/blob/main/LOGISTIC_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LOGISTIC REGRESSION **

# %%
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x,y =make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0,n_classes=2,n_clusters_per_class = 1 ,random_state=41,  hypercube = False , class_sep = 20)
print(x.shape, y.shape)
# Out:
# (100, 2) (100,)

# %%
plt.scatter(x[: , 0] , x[: , 1] , c =y , s = 100 , cmap = 'autumn')

# %%
def step(z):
  if(z >0):
    return 1
  else:
    return 0

def perceptron(x,y):
  x = np.insert(x , 0, 1 , axis = 1)

  w = np.ones(x.shape[1])
  lr = 0.1
  for i in range(1000):
    j = np.random.randint(0 ,100)

    y_hat = step(np.dot(x[j] , w))
    w = w + (lr*(y[j] - y_hat)*x[j])

  return w[0],w[1:]

# %%
intercept_,coef_ = perceptron(x,y)

# %%
print(intercept_  , coef_)
# Out:
# 1.2000000000000002 [1.0580085  0.40381514]

# %%
m = - (coef_[0] / coef_[1])
b = - (intercept_ / coef_[1])

# %%
x_input = np.linspace(3 ,-3 ,100)
y_input = m * x_input + b

# %%
plt.figure(figsize = (10,6))
plt.scatter(x[: , 0] , x[: , 1] , c =y , s = 100 , cmap = 'autumn')
plt.plot(x_input , y_input , color = 'red')
plt.ylim(-4,2 )
# Out:
# (-4.0, 2.0)

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor.fit(x,y)
# Out:
# LogisticRegression()

# %%
m = - (lor.coef_[0][0] / lor.coef_[0][1])
b = - (lor.intercept_ / lor.coef_[0][1])

# %%
x_input1 = np.linspace(3 ,-3 ,100)
y_input1 = m * x_input + b

# %%
plt.figure(figsize = (10,6))
plt.scatter(x[: , 0] , x[: , 1] , c =y , s = 100 , cmap = 'autumn')
plt.plot(x_input , y_input , color = 'red')
plt.plot(x_input1,y_input1 , color = 'black')
plt.ylim(-4,2 )
# Out:
# (-4.0, 2.0)

# %%
def sigmoid(z):
  if z >= 0:
    return 1 / (1 + np.exp(-z))
  else:
    return np.exp(z) / (1 + np.exp(z))


def sigmoid_trick(x,y):
  x = np.insert( x , 0 , 1 , axis = 1)

  w = np.ones(x.shape[1])
  lr = 0.1

  for i in range(0,100):
    j = np.random.randint(0 , x.shape[0])

    y_hat = sigmoid(np.dot(x[j] , w))
    w = w + (lr*(y[j] - y_hat)*x[j])

  return w[0],w[1:]

# %%
itercept_1_,coef_1_ = sigmoid_trick(x,y)
print(itercept_1_,coef_1_)
# Out:
# 1.447202259014822 [1.81024463 0.34177888]

# %%
m1 = - (coef_[0] / coef_[1])
b1 = - (intercept_ / coef_[1])
x_input2 = np.linspace(3 ,-3 ,100)
y_input2 = m * x_input + b

# %%
plt.figure(figsize = (10,6))
plt.scatter(x[: , 0] , x[: , 1] , c =y , s = 100 , cmap = 'autumn')
plt.plot(x_input , y_input , color = 'red')
plt.plot(x_input2,y_input2 , color = 'blue')
plt.ylim(-3,2)
#plt.plot(x_input1,y_input1 , color = 'black')
plt.ylim(-4,2 )
# Out:
# (-4.0, 2.0)
